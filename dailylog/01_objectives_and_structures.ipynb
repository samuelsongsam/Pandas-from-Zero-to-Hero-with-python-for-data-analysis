# %%
import numpy as np
import pandas as pd

# %%
from pandas import Series,DataFrame #conviniency

# %% [markdown]
# Series
# similar to array

# %%
obj=pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj=pd.Series([4,7,-5,3],index=["d","b","a","c"])
obj
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj[["a","d"]]#key to the value,metion that there's [[]]
# Out:
# a   -5
# d    4
# dtype: int64

# %%
obj[obj>0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
np.exp(obj)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
"b" in obj
# Out:
# True

# %%
obj.to_dict()
# Out:
# {'d': 4, 'b': 7, 'a': -5, 'c': 3}

# %%
obj=pd.Series(obj)

# %%
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
states = ["California", "Ohio", "Oregon", "Texas"]
obj=pd.Series(sdata,index=states)
obj
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# the fuction isnull and notnull in pandas can be used to examine the missing values

# %%
pd.isnull(obj)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
#alignment for index
obj+pd.Series(sdata)
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj.name="popu"
obj.index.name="state"
obj
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: popu, dtype: float64

# %% [markdown]
# DataFrame

# %%
data={"state":["Ohio","Ohio","Ohio","Nevada","Nevada","Nevada"],
      "year":[2000,2001,2002,2001,2002,2003],
      "pop":[1.5,1.7,3.6,2.4,2.9,3.2]}
frame=pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
print(pd.DataFrame(data,columns=["year","state","debt"]))
# Out:
#    year   state debt
# 0  2000    Ohio  NaN
# 1  2001    Ohio  NaN
# 2  2002    Ohio  NaN
# 3  2001  Nevada  NaN
# 4  2002  Nevada  NaN
# 5  2003  Nevada  NaN

# %%
frame["state"]#that is a Series
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame["eastern"]=frame["state"]=="Ohio"#add new columns
frame
# Out:
#     state  year  pop  eastern
# 0    Ohio  2000  1.5     True
# 1    Ohio  2001  1.7     True
# 2    Ohio  2002  3.6     True
# 3  Nevada  2001  2.4    False
# 4  Nevada  2002  2.9    False
# 5  Nevada  2003  3.2    False

# %%
del frame["eastern"]
frame.columns
# Out:
# Index(['state', 'year', 'pop'], dtype='object')

# %%
frame.T
# Out:
#           0     1     2       3       4       5
# state  Ohio  Ohio  Ohio  Nevada  Nevada  Nevada
# year   2000  2001  2002    2001    2002    2003
# pop     1.5   1.7   3.6     2.4     2.9     3.2

# %%
frame.to_numpy()
# Out:
# array([['Ohio', 2000, 1.5],
#        ['Ohio', 2001, 1.7],
#        ['Ohio', 2002, 3.6],
#        ['Nevada', 2001, 2.4],
#        ['Nevada', 2002, 2.9],
#        ['Nevada', 2003, 3.2]], dtype=object)
